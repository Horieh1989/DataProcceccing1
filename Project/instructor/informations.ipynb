# %% [markdown]
# 1. df.show()   : show raws and collumns
# 2. df['Age'].value_counts(25)   : how many times each uniq value appear
# 3. df.columns   :check collumns
# 4. df['name of special collumn']
# 5. df['collumn'].unique():  number of unique items here countries
# 6. df['country'].nunique() : list of the name of values in country
